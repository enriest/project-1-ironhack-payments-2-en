# %% [markdown]
# Initiating the docs and the imports for the project. First steps.

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import statistics
import plotly.io as pio

# %%
# Open and stocking both csv in df

df_cr = pd.read_csv('../Data/Cash request.csv')
df_fe = pd.read_csv('../Data/Fees.csv')
display(df_cr)
display(df_fe)
# Out:
#           id  amount             status                     created_at  \
# 0          5   100.0           rejected  2019-12-10 19:05:21.596873+00
# 1         70   100.0           rejected   2019-12-10 19:50:12.34778+00
# 2          7   100.0           rejected   2019-12-10 19:13:35.82546+00
# 3         10    99.0           rejected  2019-12-10 19:16:10.880172+00
# 4       1594   100.0           rejected  2020-05-06 09:59:38.877376+00
# ...      ...     ...                ...                            ...
# 23965  20616   100.0         money_back  2020-10-12 13:54:11.686225+00
# 23966  25243    50.0         money_back   2020-10-27 14:41:25.73491+00
# 23967  22357   100.0         money_back  2020-10-20 07:58:04.006937+00
# 23968  20256   100.0         money_back  2020-10-10 05:40:55.700422+00
# 23969  19886   100.0  direct_debit_sent  2020-10-08 14:16:52.155661+00
#
#                           updated_at  user_id                   moderated_at  \
# ...

# %% [markdown]
# Finding the index, columns, heads, shape and values

# %%
# For Cash Request
print("Index:", df_cr.index)
print("Shape:", df_cr.shape)
print("Values:", df_cr.values)
print("Columns:", df_cr.columns)
print("Head:\n", df_cr.head())
print("Type of data:\n", df_cr.dtypes)
print(df_cr.info)
""" 
So, we have missing values, a len of 23970, 2D, 16 columns,
some of those columns may need to be converted into str since they are dt
"""
# Out:
# Index: RangeIndex(start=0, stop=23970, step=1)
# Shape: (23970, 16)
# Values: [[5 100.0 'rejected' ... nan nan nan]
#  [70 100.0 'rejected' ... nan nan nan]
#  [7 100.0 'rejected' ... nan nan nan]
#  ...
#  [22357 100.0 'money_back' ... nan nan nan]
#  [20256 100.0 'money_back' ... nan nan nan]
#  [19886 100.0 'direct_debit_sent' ... nan nan nan]]
# Columns: Index(['id', 'amount', 'status', 'created_at', 'updated_at', 'user_id',
#        'moderated_at', 'deleted_account_id', 'reimbursement_date',
#        'cash_request_received_date', 'money_back_date', 'transfer_type',
#        'send_at', 'recovery_status', 'reco_creation', 'reco_last_update'],
#       dtype='object')
# Head:
#       id  amount    status                     created_at  \
# 0     5   100.0  rejected  2019-12-10 19:05:21.596873+00
# 1    70   100.0  rejected   2019-12-10 19:50:12.34778+00
# 2     7   100.0  rejected   2019-12-10 19:13:35.82546+00
# 3    10    99.0  rejected  2019-12-10 19:16:10.880172+00
# ...

# %%
# For Fees

print("Index:", df_fe.index)
print("Shape:", df_fe.shape)
print("Values:", df_fe.values)
print("Columns:", df_fe.columns)
print("Head:\n", df_fe.head())
print("Type of data:\n", df_fe.dtypes)
print("Info:", df_fe.info)
# Out:
# Index: RangeIndex(start=0, stop=21061, step=1)
# Shape: (21061, 13)
# Values: [[6537 14941.0 'instant_payment' ... nan nan 'after']
#  [6961 11714.0 'incident' ... nan nan 'after']
#  [16296 23371.0 'instant_payment' ... nan nan 'after']
#  ...
#  [18779 25331.0 'instant_payment' ... nan nan 'after']
#  [16542 23628.0 'instant_payment' ... nan nan 'after']
#  [13301 20982.0 'instant_payment' ... nan nan 'after']]
# Columns: Index(['id', 'cash_request_id', 'type', 'status', 'category', 'total_amount',
#        'reason', 'created_at', 'updated_at', 'paid_at', 'from_date', 'to_date',
#        'charge_moment'],
#       dtype='object')
# Head:
#        id  cash_request_id             type    status               category  \
# 0   6537          14941.0  instant_payment  rejected                    NaN
# 1   6961          11714.0         incident  accepted  rejected_direct_debit
# 2  16296          23371.0  instant_payment  accepted                    NaN
# ...

# %% [markdown]
# Looking for missing values
#
# 1. Identify those missing values
# Columns : used_id, moderated_at, deleted_account_id, cash_request_received_date, money_back_date, send_at,recovery_status, reco_creation, reco_last_update [those three last have a common value]
# 2. Drop any column?
# 3. Fill any column?
# 4. Impute any column?

# %%
# 1. Identifying nan
df_cr.isnull().sum()
# Out:
# id                                0
# amount                            0
# status                            0
# created_at                        0
# updated_at                        0
# user_id                        2103
# moderated_at                   7935
# deleted_account_id            21866
# reimbursement_date                0
# cash_request_received_date     7681
# money_back_date                7427
# transfer_type                     0
# send_at                        7329
# recovery_status               20640
# reco_creation                 20640
# reco_last_update              20640
# dtype: int64

# %%
df_cr.isnull().mean()
# Out:
# id                            0.000000
# amount                        0.000000
# status                        0.000000
# created_at                    0.000000
# updated_at                    0.000000
# user_id                       0.087735
# moderated_at                  0.331039
# deleted_account_id            0.912224
# reimbursement_date            0.000000
# cash_request_received_date    0.320442
# money_back_date               0.309846
# transfer_type                 0.000000
# send_at                       0.305757
# recovery_status               0.861076
# reco_creation                 0.861076
# reco_last_update              0.861076
# dtype: float64

# %% [markdown]
# Some thoughts for df_cr:
# - When user_id is nan is because the account's been deleted. So there's no nan in delected_account_id. MNAR
# - Three last columns are correlated, I can slice them. MAR
#     - They seem to be correlated with cash_request_received_sate and money_back_date.MAR
#     - Pivot maybe. When the cash is received, other values show up.
# - The id of the transfer is id and user_id for the user.
